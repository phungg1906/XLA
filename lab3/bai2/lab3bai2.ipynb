# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('colorful-ripe-tropical-fruits.jpg')
bmg = data [300:800, 130:675]
bmg[:, :] = [0, 100, 255]
print(data.shape)

bmg1 = data[300:1100, 1630:2400]
bmg1[:, :] = [255, 100, 0]

plt.imshow(bmg)
plt.show()

plt.imshow(bmg1)
plt.show()
# Out:
# (1414, 2119, 3)
