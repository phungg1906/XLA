# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('colorful-ripe-tropical-fruits.jpg', mode='F')
bmg = data [900:1150, 400:550]
print(data.shape)
plt.imshow(bmg)
plt.show()
bdata = nd.shift(bmg, (0,30))
plt.imshow(bdata)
plt.show()
# Out:
# (1414, 2119)
