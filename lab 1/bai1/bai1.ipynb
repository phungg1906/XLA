# %%
import numpy as np
import imageio.v2 as iio
import matplotlib.pylab as plt
data = iio.imread('bird.png')
bdata = (data[:,:,1])
plt.imshow(bdata)
plt.show() 
data2 = iio.imread('bird.png')
bdata2 = (data[:,:,0])
plt.imshow(bdata2)
plt.show() 
data3 = iio.imread('bird.png')
bdata3 = (data[:,:,2])
plt.imshow(bdata3)
plt.show()
